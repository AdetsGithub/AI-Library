# %%
from keras.datasets import mnist
import numpy as np
from keras.utils import to_categorical
import sys
sys.path.append('../')

# %%
from Layers.dense import Dense
from Functions.activation_functions import Logistic, Tanh
from Functions.loss_functions import MSE
from network import Network

# %%
def preprocess_data(x, y, limit):
    # reshape input data
    x = x.reshape(x.shape[0], 28 * 28, 1)
    # converting array to float and normalising to avoid large gradient values
    x = x.astype(float) / 255
    # one-hot encode output
    y = to_categorical(y)
    y = y.reshape(y.shape[0], 10, 1)
    return x[:limit], y[:limit]

# load MNIST from server
(train_x, train_y), (test_x, test_y) = mnist.load_data()

train_x, train_y = preprocess_data(train_x, train_y, 5000)
test_x, test_y = preprocess_data(test_x, test_y, 50)

network = Network([
    Dense(28 * 28, 35),
    Logistic(),
    Dense(35, 10),
    Tanh()
])

# train
network.train(MSE, train_x, train_y, epochs=100, learning_rate=0.5, verbose=True)

# test
stat = 0
for x, y in zip(test_x, test_y):
    output = network.predict(x)
    print('predicted:', np.argmax(output), '\ttrue:', np.argmax(y))
    if np.argmax(output) == np.argmax(y): stat += 1

print(stat/test_x.shape[0] * 100, '%', " successful classifications")
# Out:
# 1/100, error=0.20675018503012588
# 2/100, error=0.07992467253162139
# 3/100, error=0.06605845449368022
# 4/100, error=0.05473996244581191
# 5/100, error=0.04557329614621446
# 6/100, error=0.03986108197645729
# 7/100, error=0.03613015513096959
# 8/100, error=0.033418072763601966
# 9/100, error=0.031283291460923277
# 10/100, error=0.029533619118957743
# 11/100, error=0.028094070357472127
# 12/100, error=0.026855561281216103
# 13/100, error=0.025764125819003426
# 14/100, error=0.0248617690327761
# 15/100, error=0.02408119209882825
# 16/100, error=0.023410765231819283
# 17/100, error=0.022781005143541973
# 18/100, error=0.0221998615633519
# 19/100, error=0.021689543662849503
# 20/100, error=0.02122996224410138
# 21/100, error=0.020800976807529164
# 22/100, error=0.020398650566583788
# 23/100, error=0.02000018639359663
# 24/100, error=0.01960777089083573
# 25/100, error=0.019206211477618446
# 26/100, error=0.018828704232292378
# 27/100, error=0.01849918174876749
# 28/100, error=0.018196542726823178
# 29/100, error=0.01789197330304049
# 30/100, error=0.017608752699646214
# 31/100, error=0.017346498883782903
# 32/100, error=0.017096939702684402
# 33/100, error=0.016862847157221306
# 34/100, error=0.016632761455621814
# 35/100, error=0.016415344242308425
# 36/100, error=0.016209520513351897
# 37/100, error=0.016017224480094478
# 38/100, error=0.015828329043687875
# 39/100, error=0.015656474102045317
# 40/100, error=0.015488505173337401
# 41/100, error=0.015329966257880554
# 42/100, error=0.015172409932015313
# 43/100, error=0.015018491902963593
# 44/100, error=0.014863133620651963
# 45/100, error=0.014710349061287613
# 46/100, error=0.014562057240473306
# 47/100, error=0.014418239222319208
# 48/100, error=0.014275852273439898
# 49/100, error=0.014136125749797989
# 50/100, error=0.01400116701455293
# 51/100, error=0.013874330673958673
# 52/100, error=0.013756823102379146
# 53/100, error=0.01364714423581092
# 54/100, error=0.013543222082659057
# 55/100, error=0.013444200989893747
# 56/100, error=0.01335326343421792
# 57/100, error=0.013269951769753553
# 58/100, error=0.013186588078700419
# 59/100, error=0.013100010413353288
# 60/100, error=0.013016521904110755
# 61/100, error=0.012943531941294441
# 62/100, error=0.01287571718501809
# 63/100, error=0.012809140999206872
# 64/100, error=0.012742910223674842
# 65/100, error=0.012675603655970471
# 66/100, error=0.012605350040236924
# 67/100, error=0.012533464291324155
# 68/100, error=0.012461462007579048
# 69/100, error=0.012391793800434365
# 70/100, error=0.012325555760403503
# 71/100, error=0.012261222740916875
# 72/100, error=0.012197339989998439
# 73/100, error=0.012132743424203639
# 74/100, error=0.012066721972738012
# 75/100, error=0.012000272534648948
# 76/100, error=0.011934800013161972
# 77/100, error=0.011871280385362965
# 78/100, error=0.011808909865924004
# 79/100, error=0.011749560850590023
# 80/100, error=0.011693391140986942
# 81/100, error=0.011640286425969456
# 82/100, error=0.011588796368574796
# 83/100, error=0.011539056552178288
# 84/100, error=0.011492707698135896
# 85/100, error=0.011449308501924414
# 86/100, error=0.011407367972863456
# 87/100, error=0.011366555862504863
# 88/100, error=0.01132692153397651
# 89/100, error=0.011289016229967861
# 90/100, error=0.011253242769343993
# 91/100, error=0.01121497235217446
# 92/100, error=0.011176534816074068
# 93/100, error=0.011141457595362898
# 94/100, error=0.011101201903223518
# 95/100, error=0.011060289579164776
# 96/100, error=0.011020982569559181
# 97/100, error=0.010982051545701936
# 98/100, error=0.010941674124454197
# 99/100, error=0.010900291526589945
# 100/100, error=0.010862217929553393
# predicted: 7 	true: 7
# predicted: 2 	true: 2
# predicted: 1 	true: 1
# predicted: 0 	true: 0
# predicted: 4 	true: 4
# predicted: 1 	true: 1
# predicted: 4 	true: 4
# predicted: 9 	true: 9
# predicted: 8 	true: 5
# predicted: 9 	true: 9
# predicted: 0 	true: 0
# predicted: 8 	true: 6
# predicted: 9 	true: 9
# predicted: 0 	true: 0
# predicted: 1 	true: 1
# predicted: 5 	true: 5
# predicted: 9 	true: 9
# predicted: 7 	true: 7
# predicted: 8 	true: 3
# predicted: 4 	true: 4
# predicted: 9 	true: 9
# predicted: 6 	true: 6
# predicted: 8 	true: 6
# predicted: 5 	true: 5
# predicted: 4 	true: 4
# predicted: 0 	true: 0
# predicted: 7 	true: 7
# predicted: 4 	true: 4
# predicted: 0 	true: 0
# predicted: 1 	true: 1
# predicted: 3 	true: 3
# predicted: 1 	true: 1
# predicted: 3 	true: 3
# predicted: 0 	true: 4
# predicted: 7 	true: 7
# predicted: 2 	true: 2
# predicted: 7 	true: 7
# predicted: 1 	true: 1
# predicted: 2 	true: 2
# predicted: 1 	true: 1
# predicted: 1 	true: 1
# predicted: 7 	true: 7
# predicted: 4 	true: 4
# predicted: 2 	true: 2
# predicted: 3 	true: 3
# predicted: 5 	true: 5
# predicted: 1 	true: 1
# predicted: 2 	true: 2
# predicted: 4 	true: 4
# predicted: 4 	true: 4
# 90.0 %  successful classifications
