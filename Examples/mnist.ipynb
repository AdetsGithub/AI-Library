# %%
from keras.datasets import mnist
import numpy as np
from keras.utils import to_categorical
import sys
sys.path.append('../')

# %%
from Layers.dense import Dense
from Functions.activation_functions import *
from Functions.loss_functions import MSE
from network import Network

# %%
def preprocess_data(x, y, limit):
    # reshape input data
    x = x.reshape(x.shape[0], 28 * 28, 1)
    # converting array to float and normalising to avoid large gradient values
    x = x.astype(float) / 255
    # one-hot encode output
    y = to_categorical(y)
    y = y.reshape(y.shape[0], 10, 1)
    return x[:limit], y[:limit]

# load MNIST from server
(train_x, train_y), (test_x, test_y) = mnist.load_data()

train_x, train_y = preprocess_data(train_x, train_y, 5000)
test_x, test_y = preprocess_data(test_x, test_y, 50)

network = Network([
    Dense(28 * 28, 35),
    Logistic(),
    Dense(35, 10),
    Tanh()
])

# train
network.train(MSE, train_x, train_y, epochs=100, learning_rate=0.1, verbose=True)

# test
stat = 0
for x, y in zip(test_x, test_y):
    output = network.predict(x)
    print('predicted:', np.argmax(output), '\ttrue:', np.argmax(y))
    if np.argmax(output) == np.argmax(y): stat += 1

print(stat/test_x.shape[0] * 100, '%', " successful classifications")
# Out:
# 1/100, error=0.44450728315695426
# 2/100, error=0.10454570098471788
# 3/100, error=0.07931011117960478
# 4/100, error=0.07328080656145992
# 5/100, error=0.06921772967091584
# 6/100, error=0.06600116399836821
# 7/100, error=0.063245151018917
# 8/100, error=0.060724961214269534
# 9/100, error=0.0584089323021614
# 10/100, error=0.05637438685101704
# 11/100, error=0.05450952125981905
# 12/100, error=0.05273033071124506
# 13/100, error=0.051007202392376556
# 14/100, error=0.049283668288860494
# 15/100, error=0.04749944271173478
# 16/100, error=0.04586232624522806
# 17/100, error=0.04452312841003935
# 18/100, error=0.04334305940066452
# 19/100, error=0.04224490328032213
# 20/100, error=0.04119896421329176
# 21/100, error=0.04019634043100952
# 22/100, error=0.03923213172639975
# 23/100, error=0.03831036162671887
# 24/100, error=0.037431873589744515
# 25/100, error=0.036590844154471946
# 26/100, error=0.03577751123364146
# 27/100, error=0.03498183372298543
# 28/100, error=0.03420366428145617
# 29/100, error=0.03345411038305079
# 30/100, error=0.03273989442885233
# 31/100, error=0.03206497064382936
# 32/100, error=0.031435902973385235
# 33/100, error=0.030856146032206197
# 34/100, error=0.030322515301750827
# 35/100, error=0.029827905398978987
# 36/100, error=0.029365879051179877
# 37/100, error=0.028930728758316104
# 38/100, error=0.028516540477779826
# 39/100, error=0.028119601628384873
# 40/100, error=0.027739313531102466
# 41/100, error=0.02737450632499162
# 42/100, error=0.02702360545214405
# 43/100, error=0.026686422470485555
# 44/100, error=0.026363656042031915
# 45/100, error=0.026055952786715967
# 46/100, error=0.025762732223471967
# 47/100, error=0.025483045480580627
# 48/100, error=0.025216139640284338
# 49/100, error=0.02496119948360496
# 50/100, error=0.024717191185367537
# 51/100, error=0.02448301048317399
# 52/100, error=0.024257703205499997
# 53/100, error=0.024040456184549586
# 54/100, error=0.023830616144859488
# 55/100, error=0.023627851226972637
# 56/100, error=0.023432059995185897
# 57/100, error=0.023243137123312323
# 58/100, error=0.023060877277311154
# 59/100, error=0.02288496501354579
# 60/100, error=0.0227149880048601
# 61/100, error=0.022550495527898277
# 62/100, error=0.022391088501681658
# 63/100, error=0.022236492467867085
# 64/100, error=0.022086570948602
# 65/100, error=0.021941271836044322
# 66/100, error=0.021800551368159022
# 67/100, error=0.021664328554807512
# 68/100, error=0.021532474193041374
# 69/100, error=0.021404803911739923
# 70/100, error=0.021281065319831326
# 71/100, error=0.021160939509235806
# 72/100, error=0.021044070739503595
# 73/100, error=0.020930112417297378
# 74/100, error=0.020818767241488494
# 75/100, error=0.02070980607070824
# 76/100, error=0.020603062494530318
# 77/100, error=0.020498409630704036
# 78/100, error=0.020395727249739794
# 79/100, error=0.020294868562990953
# 80/100, error=0.020195642310648812
# 81/100, error=0.020097822585586914
# 82/100, error=0.020001180162326115
# 83/100, error=0.019905517879770174
# 84/100, error=0.019810712889525357
# 85/100, error=0.019716800282951228
# 86/100, error=0.019624088116002598
# 87/100, error=0.019533163755006425
# 88/100, error=0.019444682381165136
# 89/100, error=0.01935910664563284
# 90/100, error=0.019276620009912277
# 91/100, error=0.019197182843050872
# 92/100, error=0.019120608702639326
# 93/100, error=0.019046622689755384
# 94/100, error=0.018974907660089975
# 95/100, error=0.018905138990224644
# 96/100, error=0.01883700627037939
# 97/100, error=0.018770225468721206
# 98/100, error=0.01870454887164312
# 99/100, error=0.01863978010254871
# 100/100, error=0.01857579436453347
# predicted: 7 	true: 7
# predicted: 2 	true: 2
# predicted: 1 	true: 1
# predicted: 0 	true: 0
# predicted: 4 	true: 4
# predicted: 1 	true: 1
# predicted: 4 	true: 4
# predicted: 9 	true: 9
# predicted: 5 	true: 5
# predicted: 9 	true: 9
# predicted: 0 	true: 0
# predicted: 5 	true: 6
# predicted: 9 	true: 9
# predicted: 0 	true: 0
# predicted: 1 	true: 1
# predicted: 5 	true: 5
# predicted: 9 	true: 9
# predicted: 7 	true: 7
# predicted: 8 	true: 3
# predicted: 4 	true: 4
# predicted: 9 	true: 9
# predicted: 6 	true: 6
# predicted: 8 	true: 6
# predicted: 5 	true: 5
# predicted: 4 	true: 4
# predicted: 0 	true: 0
# predicted: 7 	true: 7
# predicted: 4 	true: 4
# predicted: 0 	true: 0
# predicted: 1 	true: 1
# predicted: 3 	true: 3
# predicted: 1 	true: 1
# predicted: 3 	true: 3
# predicted: 4 	true: 4
# predicted: 7 	true: 7
# predicted: 2 	true: 2
# predicted: 7 	true: 7
# predicted: 1 	true: 1
# predicted: 2 	true: 2
# predicted: 1 	true: 1
# predicted: 1 	true: 1
# predicted: 7 	true: 7
# predicted: 4 	true: 4
# predicted: 2 	true: 2
# predicted: 3 	true: 3
# predicted: 3 	true: 5
# predicted: 5 	true: 1
# predicted: 2 	true: 2
# predicted: 4 	true: 4
# predicted: 4 	true: 4
# 90.0 %  successful classifications
