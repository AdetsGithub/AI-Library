# %%
from keras.datasets import mnist
import numpy as np
from keras.utils import to_categorical
import sys
sys.path.append('../')

# %%
from Layers.dense import Dense
from Functions.activation_functions import Tanh
from Functions.loss_functions import MSE
from network import Network

# %%
def preprocess_data(x, y, limit):
    # reshape input data
    x = x.reshape(x.shape[0], 28 * 28, 1)
    # converting array to float and normalising to avoid large gradient values
    x = x.astype(float) / 255
    # one-hot encode output
    y = to_categorical(y)
    y = y.reshape(y.shape[0], 10, 1)
    return x[:limit], y[:limit]

# load MNIST from server
(train_x, train_y), (test_x, test_y) = mnist.load_data()

print(train_x.shape)
print(train_y.shape)

train_x, train_y = preprocess_data(train_x, train_y, 1000)
test_x, test_y = preprocess_data(test_x, test_y, 20)

print(train_x.shape)
print(train_y.shape)

network = Network([
    Dense(28 * 28, 35),
    Tanh(),
    Dense(35, 10),
    Tanh()
])

# train
network.train(MSE, train_x, train_y, epochs=100, learning_rate=0.1, verbose=True)

# test
stat = 0
for x, y in zip(test_x, test_y):
    output = network.predict(x)
    print('predicted:', np.argmax(output), '\ttrue:', np.argmax(y))
    if np.argmax(output) == np.argmax(y): stat += 1

print(stat/test_x.shape[0] * 100, '%', " successful classifications")
# Out:
# (60000, 28, 28)
# (60000,)
# (1000, 784, 1)
# (1000, 10, 1)
# 1/100, error=0.8426015543019498
# 2/100, error=0.7643918802318994
# 3/100, error=0.7081829141219634
# 4/100, error=0.6281540390198053
# 5/100, error=0.5317295881528881
# 6/100, error=0.40380428768191373
# 7/100, error=0.2772663000171453
# 8/100, error=0.17755126945419553
# 9/100, error=0.1357176177094579
# 10/100, error=0.120660145820204
# 11/100, error=0.1123433791602548
# 12/100, error=0.10718712035325395
# 13/100, error=0.10345331155042423
# 14/100, error=0.10099361504136364
# 15/100, error=0.09855103114450765
# 16/100, error=0.09650330974777348
# 17/100, error=0.09483558723204662
# 18/100, error=0.0933858559907703
# 19/100, error=0.09187440625740334
# 20/100, error=0.09040723882011477
# 21/100, error=0.08896248814688
# 22/100, error=0.08780690942111796
# 23/100, error=0.08682617669180583
# 24/100, error=0.08584327388917001
# 25/100, error=0.0850532037097685
# 26/100, error=0.08428837371110316
# 27/100, error=0.08348486660536938
# 28/100, error=0.08285255169557476
# 29/100, error=0.08209296179766819
# 30/100, error=0.08150561489760383
# 31/100, error=0.08082128200030622
# 32/100, error=0.08020354642728662
# 33/100, error=0.07951983891308066
# 34/100, error=0.07880561945890621
# 35/100, error=0.07813208814996515
# 36/100, error=0.07762750674623488
# 37/100, error=0.07701585152057218
# 38/100, error=0.07639996438877292
# 39/100, error=0.07559613336757272
# 40/100, error=0.07496127140700148
# 41/100, error=0.07419831567313064
# 42/100, error=0.07363191233517923
# 43/100, error=0.07308831465011556
# 44/100, error=0.07261459144715857
# 45/100, error=0.07201878758982996
# 46/100, error=0.07162133854717206
# 47/100, error=0.07118042052317504
# 48/100, error=0.07093108757832789
# 49/100, error=0.07057657537450718
# 50/100, error=0.07036239065682269
# 51/100, error=0.07006579485932192
# 52/100, error=0.06974246001677334
# 53/100, error=0.06940411755263609
# 54/100, error=0.06913084750557881
# 55/100, error=0.06878932121267912
# 56/100, error=0.06857325910113786
# 57/100, error=0.06817182826932675
# 58/100, error=0.06788368639800031
# 59/100, error=0.0675347103752839
# 60/100, error=0.06714973322440002
# 61/100, error=0.06676975296273231
# 62/100, error=0.06636273815184969
# 63/100, error=0.06593804068260357
# 64/100, error=0.06545001859035582
# 65/100, error=0.06534572080455643
# 66/100, error=0.06490026813094803
# 67/100, error=0.06465074943659121
# 68/100, error=0.06424993227801833
# 69/100, error=0.06408174419838097
# 70/100, error=0.06374235039119078
# 71/100, error=0.06352587400241325
# 72/100, error=0.06318765259135391
# 73/100, error=0.0630190284131671
# 74/100, error=0.06268873068609734
# 75/100, error=0.06246565553373528
# 76/100, error=0.06209669064408295
# 77/100, error=0.061981160553357645
# 78/100, error=0.06169130828484151
# 79/100, error=0.061559391757922056
# 80/100, error=0.0612214226013323
# 81/100, error=0.061083128449397735
# 82/100, error=0.06080080024385382
# 83/100, error=0.0607555381417355
# 84/100, error=0.06051610585520659
# 85/100, error=0.060182831088519254
# 86/100, error=0.059998063543462855
# 87/100, error=0.05987856207919034
# 88/100, error=0.059680013245120775
# 89/100, error=0.059448475897496154
# 90/100, error=0.05923583587330141
# 91/100, error=0.05911325492910384
# 92/100, error=0.05888926663870496
# 93/100, error=0.05873531230616987
# 94/100, error=0.05856235810527809
# 95/100, error=0.05838492118668473
# 96/100, error=0.058278331320170663
# 97/100, error=0.05805047351318736
# 98/100, error=0.057967648478943146
# 99/100, error=0.05783157169130904
# 100/100, error=0.057637872293349754
# predicted: 7 	true: 7
# predicted: 2 	true: 2
# predicted: 1 	true: 1
# predicted: 0 	true: 0
# predicted: 7 	true: 4
# predicted: 1 	true: 1
# predicted: 3 	true: 4
# predicted: 9 	true: 9
# predicted: 6 	true: 5
# predicted: 7 	true: 9
# predicted: 0 	true: 0
# predicted: 0 	true: 6
# predicted: 9 	true: 9
# predicted: 0 	true: 0
# predicted: 1 	true: 1
# predicted: 3 	true: 5
# predicted: 6 	true: 9
# predicted: 7 	true: 7
# predicted: 6 	true: 3
# predicted: 4 	true: 4
# 60.0 %  successful classifications
